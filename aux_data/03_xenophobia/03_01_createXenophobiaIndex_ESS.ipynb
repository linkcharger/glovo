# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ## create column subset

# %%
ddf = dd.read_parquet('03_xenophobia/ESS/data/parquet')
ddf.head()
# Out:
#         name  essround  edition    proddate cntry  idno  tvtot  tvpol  rdtot  \
# 0  ESS1e06_6       1.0      6.6  01.12.2018    AT   1.0    1.0    1.0    1.0
# 1  ESS1e06_6       1.0      6.6  01.12.2018    AT   2.0    3.0    2.0    4.0
# 2  ESS1e06_6       1.0      6.6  01.12.2018    AT   3.0    7.0    3.0    0.0
# 3  ESS1e06_6       1.0      6.6  01.12.2018    AT   4.0    1.0    1.0    1.0
# 4  ESS1e06_6       1.0      6.6  01.12.2018    AT   6.0    0.0   66.0    1.0
#
#    rdpol  ...  sofrpr  sofrprv  ppldsrv  jstprev  pcmpinj  domain  prob  \
# 0    1.0  ...     NaN      NaN      NaN      NaN      NaN     NaN   NaN
# 1    1.0  ...     NaN      NaN      NaN      NaN      NaN     NaN   NaN
# 2   66.0  ...     NaN      NaN      NaN      NaN      NaN     NaN   NaN
# 3    1.0  ...     NaN      NaN      NaN      NaN      NaN     NaN   NaN
# 4    1.0  ...     NaN      NaN      NaN      NaN      NaN     NaN   NaN
#
#    stratum  psu  year
# 0      NaN  NaN  2002
# 1      NaN  NaN  2002
# 2      NaN  NaN  2002
# 3      NaN  NaN  2002
# 4      NaN  NaN  2002
#
# [5 rows x 2373 columns]

# %%
len(ddf)
# Out:
# 430870

# %%
ddf.year.value_counts(normalize=True, sort=False).compute() * 100
# Out:
# 2002     9.831040
# 2004    11.032794
# 2006     9.979808
# 2008    13.171490
# 2010    12.174902
# 2012    12.688978
# 2014     9.326479
# 2016    10.301715
# 2018    11.492794
# Name: year, dtype: float64

# %%
demographicsCols = [
    'cntry',    # country
    'idno',     # id number of individual
    'year', 
    'anctry1',  # primary ancestry
    'anctry2',  # secondary ancestry
    'region'    # region (that they live in currently?)
    ]
immiCols = [
    'imsmetn',  # Allow many/few immigrants of same race/ethnic group as majority
    'imdfetn',  # Allow many/few immigrants of different race/ethnic group from majority  
    'impcntr',  # Allow many/few immigrants from poorer countries outside Europe
    'imbgeco',  # Immigration bad or good for country's economy 
    'imueclt',  # Country's cultural life undermined or enriched by immigrants
    'imwbcnt',  # Immigrants make country worse or better place to live
    ]

subset = ddf[immiCols + demographicsCols]
subset.head()
# Out:
#    imsmetn  imdfetn  impcntr  imbgeco  imueclt  imwbcnt cntry  idno  year  \
# 0      4.0      3.0      3.0      4.0      9.0      7.0    AT   1.0  2002
# 1      2.0      2.0      2.0     10.0     10.0      5.0    AT   2.0  2002
# 2      3.0      3.0      3.0      7.0      5.0      5.0    AT   3.0  2002
# 3      1.0      2.0      1.0     10.0     10.0     10.0    AT   4.0  2002
# 4      8.0      8.0      8.0     88.0     88.0     88.0    AT   6.0  2002
#
#    anctry1  anctry2 region
# 0      NaN      NaN   None
# 1      NaN      NaN   None
# 2      NaN      NaN   None
# 3      NaN      NaN   None
# 4      NaN      NaN   None

# %%
len(subset)
# Out:
# 430870

# %%
subset.dtypes
# Out:
# imsmetn    float64
# imdfetn    float64
# impcntr    float64
# imbgeco    float64
# imueclt    float64
# imwbcnt    float64
# cntry       object
# idno       float64
# year         int64
# anctry1    float64
# anctry2    float64
# region      object
# dtype: object

# %%
subset.to_csv('03_xenophobia/ESS/data/columnSubset.csv', single_file=True)
# Out:
# ['c:\\Users\\astro\\Dropbox\\glovo\\aux_data\\03_xenophobia\\ESS\\columnSubset.csv']

# %% [markdown]
# ## start with column subset

# %%
df = pd.read_csv('03_xenophobia/ESS/data/columnSubset.csv', index_col=0, low_memory=False)
df.head()
# Out:
#    imsmetn  imdfetn  impcntr  imbgeco  imueclt  imwbcnt cntry  idno  year  \
# 0      4.0      3.0      3.0      4.0      9.0      7.0    AT   1.0  2002
# 1      2.0      2.0      2.0     10.0     10.0      5.0    AT   2.0  2002
# 2      3.0      3.0      3.0      7.0      5.0      5.0    AT   3.0  2002
# 3      1.0      2.0      1.0     10.0     10.0     10.0    AT   4.0  2002
# 4      8.0      8.0      8.0     88.0     88.0     88.0    AT   6.0  2002
#
#    anctry1  anctry2 region
# 0      NaN      NaN    NaN
# 1      NaN      NaN    NaN
# 2      NaN      NaN    NaN
# 3      NaN      NaN    NaN
# 4      NaN      NaN    NaN

# %%
len(df)
# Out:
# 430870

# %% [markdown]
# ### decode region and ethnicity

# %%
with open('03_xenophobia/ESS/regions.csv') as f:
    regionLookup = {line.split(', ')[0]: line.split(', ')[1].strip() for line in f.readlines()}
regionLookup
# Out:
# {'AT11': 'Burgenland',
#  'AT12': 'Niederösterreich',
#  'AT13': 'Wien',
#  'AT21': 'Kärnten',
#  'AT22': 'Steiermark',
#  'AT31': 'Oberösterreich',
#  'AT32': 'Salzburg',
#  'AT33': 'Tirol',
#  'AT34': 'Vorarlberg',
#  'BE10': 'Région de Bruxelles-Capitale /Brussels Hoofdstedelijk Gewest',
#  'BE21': 'Prov. Antwerpen',
#  'BE22': 'Prov. Limburg',
#  'BE23': 'Prov. Oost-Vlaanderen',
#  'BE24': 'Prov. Vlaams-Brabant',
#  'BE25': 'Prov. West-Vlaanderen',
#  'BE31': 'Prov. Brabant Wallon',
#  'BE32': 'Prov. Hainaut',
#  'BE33': 'Prov. Liège',
#  'BE34': 'Prov. Luxembourg',
#  'BE35': 'Prov. Namur',
#  'BG311': 'Vidin',
#  'BG312': 'Montana',
#  'BG313': 'Vratsa',
#  'BG314': 'Pleven',
#  'BG315': 'Lovech',
#  'BG321': 'Veliko Tarnovo',
#  'BG322': 'Gabrovo',
#  'BG323': 'Ruse',
#  'BG324': 'Razgrad',
#  'BG325': 'Silistra',
#  'BG331': 'Varna',
#  'BG332': 'Dobrich',
#  'BG333': 'Shumen',
#  'BG334': 'Targovishte',
#  'BG341': 'Burgas',
#  'BG342': 'Sliven',
#  'BG343': 'Yambol',
#  'BG344': 'Stara Zagora',
#  'BG411': 'Sofia (capital)',
#  'BG412': 'Sofia (region)',
#  'BG413': 'Blagoevgrad',
#  'BG414': 'Pernik',
#  'BG415': 'Kyustendil',
#  'BG421': 'Plovdiv',
#  'BG422': 'Haskovo',
#  'BG423': 'Pazardzhik',
#  'BG424': 'Smolyan',
#  'BG425': 'Kardzhali',
#  'CH01': 'Région lémanique',
#  'CH02': 'Espace Mittelland',
#  'CH03': 'Nordwestschweiz',
#  'CH04': 'Zürich',
#  'CH05': 'Ostschweiz',
#  'CH06': 'Zentralschweiz',
#  'CH07': 'Ticino',
#  'CY0': 'Cyprus',
#  'CZ010': 'Hlavní mesto Praha',
#  'CZ020': 'Stredoceský kraj',
#  'CZ031': 'Jihoceský kraj',
#  'CZ032': 'Plzenský kraj',
#  'CZ041': 'Karlovarský kraj',
#  'CZ042': 'Ústecký kraj',
#  'CZ051': 'Liberecký kraj',
#  'CZ052': 'Královéhradecký kraj',
#  'CZ053': 'Pardubický kraj',
#  'CZ063': 'Vysocina',
#  'CZ064': 'Jihomoravský kraj',
#  'CZ071': 'Olomoucký kraj',
#  'CZ072': 'Zlínský kraj',
#  'CZ080': 'Moravskoslezský kraj',
#  'DE1': 'Baden-Württemberg',
#  'DE2': 'Bayern',
#  'DE3': 'Berlin',
#  'DE4': 'Brandenburg',
#  'DE5': 'Bremen',
#  'DE6': 'Hamburg',
#  'DE7': 'Hessen',
#  'DE8': 'Mecklenburg-Vorpommern',
#  'DE9': 'Niedersachsen',
#  'DEA': 'Nordrhein-Westfalen',
#  'DEB': 'Rheinland-Pfalz',
#  'DEC': 'Saarland',
#  'DED': 'Sachsen',
#  'DEE': 'Sachsen-Anhalt',
#  'DEF': 'Schleswig-Holstein',
#  'DEG': 'Thüringen',
#  'EE001': 'Põhja-Eesti',
#  'EE004': 'Lääne-Eesti',
#  'EE006': 'Kesk-Eesti',
#  'EE007': 'Kirde-Eesti',
#  'EE008': 'Lõuna-Eesti',
#  'FI193': 'Keski-Suomi',
#  'FI194': 'Etelä-Pohjanmaa',
#  'FI195': 'Pohjanmaa',
#  'FI196': 'Satakunta',
#  'FI197': 'Pirkanmaa',
#  'FI1B1': 'Helsinki-Uusimaa',
#  'FI1C1': 'Varsinais-Suomi',
#  'FI1C2': 'Kanta-Häme',
#  'FI1C3': 'Päijät-Häme',
#  'FI1C4': 'Kymenlaakso',
#  'FI1C5': 'Etelä-Karjala',
#  'FI1D1': 'Etelä-Savo',
#  'FI1D2': 'Pohjois-Savo',
#  'FI1D3': 'Pohjois-Karjala',
#  'FI1D4': 'Kainuu',
#  'FI1D5': 'Keski-Pohjanmaa',
#  'FI1D6': 'Pohjois-Pohjanmaa',
#  'FI1D7': 'Lappi',
#  'FI200': 'Åland',
#  'FR10': 'Île de France',
#  'FRB0': 'Centre-Val de Loire',
#  'FRC1': 'Bourgogne',
#  'FRC2': 'Franche-Comté',
#  'FRD1': 'Basse-Normandie',
#  'FRD2': 'Haute-Normandie',
#  'FRE1': 'Nord-Pas de Calais',
#  'FRE2': 'Picardie',
#  'FRF1': 'Alsace',
#  'FRF2': 'Champagne-Ardenne',
#  'FRF3': 'Lorraine',
#  'FRG0': 'Pays de la Loire',
#  'FRH0': 'Bretagne',
#  'FRI1': 'Aquitaine',
#  'FRI2': 'Limousin',
#  'FRI3': 'Poitou-Charentes',
#  'FRJ1': 'Languedoc-Roussillon',
#  'FRJ2': 'Midi-Pyrénées',
#  'FRK1': 'Auvergne',
#  'FRK2': 'Rhône-Alpes',
#  'FRL0': 'Provence-Alpes-Côte d’Azur',
#  'HU110': 'Budapest',
#  'HU120': 'Pest',
#  'HU211': 'Fejer',
#  'HU212': 'Komarom-Esztergom',
#  'HU213': 'Veszprem',
#  'HU221': 'Gyor-Moson-Sopron',
#  'HU222': 'Vas',
#  'HU223': 'Zala',
#  'HU231': 'Baranya',
#  'HU232': 'Somogy',
#  'HU233': 'Tolna',
#  'HU311': 'Borsod-Abauj-Zemplen',
#  'HU312': 'Heves',
#  'HU313': 'Nograd',
#  'HU321': 'Hajdu-Bihar',
#  'HU322': 'Jasz-Nagykun-Szolnok',
#  'HU323': 'Szabolcs-Szatmár-Bereg',
#  'HU331': 'Bács-Kiskun',
#  'HU332': 'Békés',
#  'HU333': 'Csongrád',
#  'IE041': 'Border',
#  'IE042': 'West',
#  'IE051': 'Mid-west',
#  'IE052': 'South East',
#  'IE053': 'South-West',
#  'IE061': 'Dublin',
#  'IE062': 'Mid-East',
#  'IE063': 'Midlands',
#  'ITC': 'Nord-Ovest',
#  'ITF': 'Sud',
#  'ITG': 'Isole',
#  'ITH': 'Nord-Est',
#  'ITI': 'Centro',
#  'NL11': 'Groningen',
#  'NL12': 'Friesland',
#  'NL13': 'Drenthe',
#  'NL21': 'Overijssel',
#  'NL22': 'Gelderland',
#  'NL23': 'Flevoland',
#  'NL31': 'Utrecht',
#  'NL32': 'Noord-Holland',
#  'NL33': 'Zuid-Holland',
#  'NL34': 'Zeeland',
#  'NL41': 'Noord-Brabant',
#  'NL42': 'Limburg',
#  'NO01': 'Oslo og Akershus',
#  'NO02': 'Hedmark og Oppland',
#  'NO03': 'Sør-Østlandet',
#  'NO04': 'Agder og Rogaland',
#  'NO05': 'Vestlandet',
#  'NO06': 'Trøndelag',
#  'NO07': 'Nord-Norge',
#  'PL11': 'Lodzkie',
#  'PL12': 'Mazowieckie',
#  'PL21': 'Malopolskie',
#  'PL22': 'Slaskie',
#  'PL31': 'Lubelskie',
#  'PL32': 'Podkarpackie',
#  'PL33': 'Swietokrzyskie',
#  'PL34': 'Podlaskie',
#  'PL41': 'Wielkopolskie',
#  'PL42': 'Zachodniopomorskie',
#  'PL43': 'Lubuskie',
#  'PL51': 'Dolnoslaskie',
#  'PL52': 'Opolskie',
#  'PL61': 'Kujawsko-pomorskie',
#  'PL62': 'Warminsko-mazurskie',
#  'PL63': 'Pomorskie',
#  'RS11': 'Beogradski region',
#  'RS12': 'Region Vojvodine',
#  'RS21': 'Region Šumadije i Zapadne Srbije',
#  'RS22': 'Region Južne i Istočne Srbije',
#  'SI011': 'Pomurska',
#  'SI012': 'Podravska',
#  'SI013': 'Koroska',
#  'SI014': 'Savinjska',
#  'SI015': 'Zasavska',
#  'SI016': 'Spodnjeposavska',
#  'SI017': 'Jugovzhodna Slovenija',
#  'SI018': 'Notranjsko-kraska',
#  'SI021': 'Osrednjeslovenska',
#  'SI022': 'Gorenjska',
#  'SI023': 'Goriska',
#  'SI024': 'Obalno-kraska',
#  'UKC': 'North East (England)',
#  'UKD': 'North West (England)',
#  'UKE': 'Yorkshire and the Humber',
#  'UKF': 'East Midlands (England)',
#  'UKG': 'West Midlands (England)',
#  'UKH': 'East of England',
#  'UKI': 'London',
#  'UKJ': 'South East (England)',
#  'UKK': 'South West (England)',
#  'UKL': 'Wales',
#  'UKM': 'Scotland',
#  'UKN': 'Northern Ireland',
#  'SE11': 'Stockholms län',
#  'SE12': 'Östra Mellansverige',
#  'SE21': 'Småland med Öarna',
#  'SE22': 'Sydsverige',
#  'SE23': 'Västsverige',
#  'SE31': 'Norra Mellansverige',
#  'SE32': 'Mellersta Norrland',
#  'SE33': 'Övre Norrland',
#  'LT001': 'Alytaus apskritis',
#  'LT002': 'Kauno apskritis',
#  'LT003': 'Klaipedos apskritis',
#  'LT004': 'Marijampoles apskritis',
#  'LT005': 'Panevežio apskritis',
#  'LT006': 'Šiauliu apskritis',
#  'LT007': 'Taurages apskritis',
#  'LT008': 'Telšiu apskritis',
#  'LT009': 'Utenos apskritis',
#  'LT00A': 'Vilniaus apskritis',
#  'ME0': 'Montenegro',
#  'SK010': 'Bratislavský kraj',
#  'SK021': 'Trnavský kraj',
#  'SK022': 'Trenčiansky kraj',
#  'SK023': 'Nitriansky kraj',
#  'SK031': 'Žilinský kraj',
#  'SK032': 'Banskobystrický kraj',
#  'SK041': 'Prešovský kraj',
#  'SK042': 'Košický kraj',
#  'PT11': 'Norte',
#  'PT15': 'Algarve',
#  'PT16': 'Centro',
#  'PT17': 'Lisboa',
#  'PT18': 'Alentejo',
#  'LV003': 'Kurzeme',
#  'LV005': 'Latgale',
#  'LV006': 'Rīga',
#  'LV007': 'Pierīga',
#  'LV008': 'Vidzeme',
#  'LV009': 'Zemgale',
#  'HR041': 'Grad Zagreb',
#  'HR042': 'Zagrebačka županija',
#  'HR043': 'Krapinsko-zagorska županija',
#  'HR044': 'Varaždinska županija',
#  'HR045': 'Koprivničko-križevačka županija',
#  'HR046': 'Međimurska županija',
#  'HR047': 'Bjelovarsko-bilogorska županija',
#  'HR048': 'Virovitičko-podravska županija',
#  'HR049': 'Požeško-slavonska županija',
#  'HR04A': 'Brodsko-posavska županija',
#  'HR04B': 'Osječko-baranjska županija',
#  'HR04C': 'Vukovarsko-srijemska županija',
#  'HR04D': 'Karlovačka županija',
#  'HR04E': 'Sisačko-moslavačka županija',
#  'HR031': 'Primorsko-goranska županija',
#  'HR032': 'Ličko-senjska županija',
#  'HR033': 'Zadarska županija',
#  'HR034': 'Šibensko-kninska županija',
#  'HR035': 'Splitsko-dalmatinska županija',
#  'HR036': 'Istarska županija',
#  'HR037': 'Dubrovačko-neretvanska županija',
#  'ES11': 'Galicia',
#  'ES12': 'Principado de Asturias',
#  'ES13': 'Cantabria',
#  'ES21': 'País Vasco',
#  'ES22': 'Comunidad Foral de Navarra',
#  'ES23': 'La Rioja',
#  'ES24': 'Aragón',
#  'ES30': 'Comunidad de Madrid',
#  'ES41': 'Castilla y León',
#  'ES42': 'Castilla-La Mancha',
#  'ES43': 'Extremadura',
#  'ES51': 'Cataluña',
#  'ES52': 'Comunidad Valenciana',
#  'ES53': 'Illes Balears',
#  'ES61': 'Andalucía',
#  'ES62': 'Región de Murcia',
#  'ES63': 'Ciudad Autónoma de Ceuta',
#  'ES64': 'Ciudad Autónoma de Melilla',
#  'ES70': 'Canarias',
#  'DK01': 'Hovedstaden',
#  'DK02': 'Sjælland',
#  'DK03': 'Syddanmark',
#  'DK04': 'Midtjylland',
#  'DK05': 'Nordjylland',
#  'IS001': 'Höfuðborgarsvæði (Capital Region)',
#  'IS002': 'Landsbyggð (rest of country)'}

# %%
with open('03_xenophobia/ESS/ethnicities.csv') as f:
    ethnicityLookup = {float(line.split(', ')[0]): line.split(', ')[1].strip() for line in f.readlines()}
ethnicityLookup
# Out:
# {10000.0: 'European',
#  11000.0: 'West European',
#  11010.0: 'Austrian nfs',
#  11018.0: 'Austrian city or region nec',
#  11019.0: 'Austrian nec',
#  11020.0: 'Belgian nfs',
#  11021.0: 'Flemish',
#  11022.0: 'Walloon',
#  11023.0: 'Brussels/Bruxellois',
#  11028.0: 'Belgian city or region nec',
#  11029.0: 'Belgian nec',
#  11030.0: 'British nfs',
#  11031.0: 'English',
#  11032.0: 'Northern Irish',
#  11033.0: 'Scottish',
#  11034.0: 'Ulster',
#  11035.0: 'Welsh',
#  11038.0: 'British city or region nec',
#  11039.0: 'British nec',
#  11040.0: 'Dutch nfs',
#  11048.0: 'Dutch city or region nec',
#  11049.0: 'Dutch nec',
#  11050.0: 'French nfs',
#  11051.0: 'Breton',
#  11052.0: 'Corse',
#  11058.0: 'French city or region nec',
#  11059.0: 'French nec',
#  11060.0: 'Frisian',
#  11070.0: 'German nfs',
#  11077.0: 'German diaspora/ethnic Germans',
#  11078.0: 'German city or region nec',
#  11079.0: 'German nec',
#  11080.0: 'Irish nfs',
#  11081.0: 'Irish traveller',
#  11088.0: 'Irish city or region nec',
#  11089.0: 'Irish nec',
#  11090.0: 'Luxembourgish nfs',
#  11098.0: 'Luxembourgish city or region nec',
#  11099.0: 'Luxembourgish nec',
#  11100.0: 'Swiss nfs',
#  11101.0: 'Swiss language region nec',
#  11102.0: 'Swiss Canton',
#  11108.0: 'Swiss city or region nec',
#  11109.0: 'Swiss nec',
#  11110.0: 'Yeniche',
#  11990.0: 'West European nec',
#  12000.0: 'North European (Nordic)',
#  12010.0: 'Danish nfs',
#  12011.0: 'Faroese',
#  12012.0: 'Greenlander',
#  12018.0: 'Danish city or region nec',
#  12019.0: 'Danish nec',
#  12020.0: 'Finnish nfs',
#  12021.0: 'Swedish-speaking Finnish',
#  12022.0: 'Ingrian',
#  12028.0: 'Finnish city or region nec',
#  12029.0: 'Finnish nec',
#  12030.0: 'Icelandic nfs',
#  12038.0: 'Icelandic city or region nec',
#  12039.0: 'Icelandic nec',
#  12040.0: 'Norwegian nfs',
#  12048.0: 'Norwegian city or region nec',
#  12049.0: 'Norwegian nec',
#  12050.0: 'Sami',
#  12060.0: 'Swedish nfs',
#  12068.0: 'Swedish city or region nec',
#  12069.0: 'Swedish nec',
#  12990.0: 'North European nec',
#  13000.0: 'South European',
#  13010.0: 'Basque',
#  13020.0: 'Greek Cypriot nfs',
#  13028.0: 'Greek Cypriot city or region nec',
#  13029.0: 'Greek Cypriot nec',
#  13030.0: 'Greek nfs',
#  13031.0: 'Greek Muslim',
#  13038.0: 'Greek city or region nec',
#  13039.0: 'Greek nec',
#  13040.0: 'Italian nfs',
#  13041.0: 'Ladin',
#  13042.0: 'Sicilian',
#  13043.0: 'South Tyrolian',
#  13047.0: 'Italian diaspora/ethnic Italian',
#  13048.0: 'Italian city or region nec',
#  13049.0: 'Italian nec',
#  13050.0: 'Maltese',
#  13060.0: 'Portuguese nfs',
#  13068.0: 'Portuguese city or region nec',
#  13069.0: 'Portuguese nec',
#  13070.0: 'Spanish nfs',
#  13071.0: 'Andalusian',
#  13072.0: 'Balearic',
#  13073.0: 'Canarian',
#  13074.0: 'Catalan',
#  13075.0: 'Galician',
#  13076.0: 'Navarran',
#  13077.0: 'Valencian',
#  13078.0: 'Spanish city or region nec',
#  13079.0: 'Spanish nec',
#  13990.0: 'South European nec',
#  14000.0: 'South-East European',
#  14010.0: 'Albanian nfs',
#  14018.0: 'Albanian city or region nec',
#  14019.0: 'Albanian nec',
#  14020.0: 'Bosniak/Bosnian',
#  14030.0: 'Bulgarian nfs',
#  14031.0: 'Bulgarian Muslim',
#  14038.0: 'Bulgarian city or region nec',
#  14039.0: 'Bulgarian nec',
#  14040.0: 'Croatian nfs',
#  14048.0: 'Croatian city or region nec',
#  14049.0: 'Croatian nec',
#  14050.0: 'Kosovar nfs',
#  14058.0: 'Kosovar city or region nec',
#  14059.0: 'Kosovar nec',
#  14060.0: 'Macedonian nfs',
#  14061.0: 'Macedonian Muslim',
#  14068.0: 'Macedonian city or region nec',
#  14069.0: 'Macedonian nec',
#  14070.0: 'Moldovan',
#  14080.0: 'Montenegrin nfs',
#  14081.0: 'Montenegrin Muslim',
#  14088.0: 'Montenegrin city or region nec',
#  14089.0: 'Montenegrin nec',
#  14090.0: 'Romanian nfs',
#  14098.0: 'Romanian city or region nec',
#  14099.0: 'Romanian nec',
#  14100.0: 'Roma/Gypsy/Sinti',
#  14110.0: 'Serbian nfs',
#  14111.0: 'Bosnian Serb',
#  14119.0: 'Serbian nec',
#  14120.0: 'Slovene nfs',
#  14128.0: 'Slovenian city or region nec',
#  14129.0: 'Slovene nec',
#  14130.0: 'Vlach',
#  14140.0: 'Ashkali/Balkan Egyptian',
#  14150.0: 'Gorani',
#  14160.0: 'Yugoslav',
#  14170.0: 'Bunjevac',
#  14990.0: 'South-East European nec',
#  15000.0: 'East European',
#  15010.0: 'Belarusian',
#  15020.0: 'Czech nfs',
#  15028.0: 'Czech city or region nec',
#  15029.0: 'Czech nec',
#  15030.0: 'Estonian nfs',
#  15038.0: 'Estonian city or region nec',
#  15039.0: 'Estonian nec',
#  15040.0: 'Hungarian nfs',
#  15047.0: 'Hungarian diaspora/ethnic Hungarian',
#  15048.0: 'Hungarian city or region nec',
#  15049.0: 'Hungarian nec',
#  15050.0: 'Latvian nfs',
#  15051.0: 'Latgalian',
#  15058.0: 'Latvian city or region nec',
#  15059.0: 'Latvian nec',
#  15060.0: 'Lithuanian nfs',
#  15068.0: 'Lithuanian city or region nec',
#  15069.0: 'Lithuanian nec',
#  15080.0: 'Moravian',
#  15090.0: 'Polish nfs',
#  15091.0: 'Lemko',
#  15092.0: 'Karaim',
#  15093.0: 'Kashubian',
#  15098.0: 'Polish city or region nec',
#  15099.0: 'Polish nec',
#  15100.0: 'Ruthenian/Rusyn',
#  15110.0: 'Russian nfs',
#  15111.0: 'Estonian Russian',
#  15112.0: 'Latvian Russian',
#  15113.0: 'Ukrainian Russian',
#  15117.0: 'Russian diaspora/ethnic Russian',
#  15118.0: 'Russian city or region nec',
#  15119.0: 'Russian nec',
#  15120.0: 'Silesian',
#  15130.0: 'Slovak nfs',
#  15138.0: 'Slovak city or region nec',
#  15139.0: 'Slovak nec',
#  15140.0: 'Ukrainian nfs',
#  15148.0: 'Ukrainian city or region nec',
#  15149.0: 'Ukrainian nec',
#  15150.0: 'Sorbian/Wendish',
#  15990.0: 'East European nec',
#  20000.0: 'North African',
#  21000.0: 'Arab',
#  21010.0: 'Algerian',
#  21020.0: 'Arab Israeli',
#  21030.0: 'Bahraini',
#  21040.0: 'Bedouin',
#  21050.0: 'Egyptian',
#  21060.0: 'Emirati',
#  21070.0: 'Iraqi',
#  21080.0: 'Jordanian',
#  21090.0: 'Kuwaiti',
#  21100.0: 'Lebanese',
#  21110.0: 'Libyan',
#  21120.0: 'Mauritanian',
#  21130.0: 'Moroccan',
#  21140.0: 'Omani',
#  21150.0: 'Palestinian',
#  21160.0: 'Qatari',
#  21170.0: 'Sahrawi/Sahraoui',
#  21180.0: 'Saudi Arabian',
#  21190.0: 'Syrian',
#  21200.0: 'Tunisian',
#  21210.0: 'Yemeni',
#  21220.0: 'Muslim nfs',
#  21990.0: 'Arab nec',
#  22000.0: 'Jewish',
#  22010.0: 'Jewish Israeli nfs',
#  22011.0: 'Ashkenazi',
#  22012.0: 'Sephardi',
#  22013.0: 'Mizrahi',
#  22990.0: 'Jewish nec',
#  23000.0: 'Turkish',
#  23001.0: 'Turkish Cypriot',
#  23007.0: 'Turkish diaspora/ethnic Turk',
#  23008.0: 'Turkish city or region nec',
#  23009.0: 'Turkish nec',
#  24000.0: 'Iranian and Central Asian',
#  24010.0: 'Afghan',
#  24020.0: 'Azeri/Azerbaijani',
#  24030.0: 'Hazara',
#  24040.0: 'Iranian',
#  24050.0: 'Kazakh',
#  24060.0: 'Kyrgyz',
#  24070.0: 'Pathan',
#  24080.0: 'Tajik',
#  24090.0: 'Tatar',
#  24100.0: 'Turkmen',
#  24110.0: 'Uighur',
#  24120.0: 'Uzbek',
#  24130.0: 'Bashkir',
#  24140.0: 'Chuvash',
#  24150.0: 'Mordva',
#  24990.0: 'Iranian and Central Asian nec',
#  25000.0: 'Other North African and Middle Eastern',
#  25010.0: 'Armenian',
#  25020.0: 'Assyrian/Chaldean',
#  25030.0: 'Berber',
#  25040.0: 'Coptic',
#  25050.0: 'Druze',
#  25060.0: 'Georgian',
#  25070.0: 'Israeli nfs',
#  25078.0: 'Israeli city or region nec',
#  25079.0: 'Israeli nec',
#  25080.0: 'Kurdish',
#  25090.0: 'Mandaean',
#  25100.0: 'Avar',
#  25110.0: 'Chechen',
#  25120.0: 'Maronite',
#  25990.0: 'Other North African and Middle Eastern nec',
#  30000.0: 'Sub-Saharan African',
#  31000.0: 'West and Central African',
#  31010.0: 'Akan',
#  31020.0: 'Angolan',
#  31030.0: 'Beninese',
#  31040.0: 'Bissau-Guinean',
#  31050.0: 'Burkinabe',
#  31060.0: 'Burundian',
#  31070.0: 'Cabo Verdean',
#  31080.0: 'Cameroonian',
#  31090.0: 'Central African',
#  31100.0: 'Chadian',
#  31110.0: 'Congolese',
#  31120.0: 'Ghanaian',
#  31130.0: 'Guinean',
#  31140.0: 'Ivorian',
#  31150.0: 'Liberian',
#  31160.0: 'Malian',
#  31170.0: 'Nigerian',
#  31180.0: 'Rwandan',
#  31190.0: 'Senegalese',
#  31200.0: 'Sierra Leonean',
#  31210.0: 'Yoruban',
#  31990.0: 'West and Central African nec',
#  32000.0: "Africa's Horn",
#  32010.0: 'Afar',
#  32020.0: 'Amhara',
#  32030.0: 'Djiboutian',
#  32040.0: 'Eritrean',
#  32050.0: 'Ethiopian',
#  32060.0: 'Fur',
#  32070.0: 'Nubian',
#  32080.0: 'Oromo',
#  32090.0: 'Somali',
#  32100.0: 'Sudanese',
#  32110.0: 'Tigre',
#  32120.0: 'Tigray-Tigrinya',
#  32990.0: "Africa's Horn nec",
#  33000.0: 'East and South African',
#  33010.0: 'Comoran',
#  33020.0: 'Dinka',
#  33030.0: 'Kenyan',
#  33040.0: 'Malawian',
#  33050.0: 'Masai',
#  33060.0: 'Motswana',
#  33070.0: 'Mozambican',
#  33080.0: 'Nuer',
#  33090.0: 'Seychellois',
#  33100.0: 'South African nfs',
#  33101.0: 'Afrikaaner',
#  33102.0: 'British South African',
#  33109.0: 'South African nec',
#  33110.0: 'Tanzanian',
#  33120.0: 'Ugandan',
#  33130.0: 'Zambian',
#  33140.0: 'Zimbabwean',
#  33150.0: 'Zulu',
#  33160.0: 'Malagasy',
#  33990.0: 'East and South African nec',
#  40000.0: 'South and South-East Asian',
#  41000.0: 'South Asian',
#  41010.0: 'Bangladeshi',
#  41020.0: 'Bhutanese',
#  41030.0: 'Indian nfs',
#  41031.0: 'Bengali',
#  41032.0: 'Gujerati',
#  41033.0: 'Malayali',
#  41034.0: 'Punjabi',
#  41035.0: 'Sikh',
#  41036.0: 'Telegu',
#  41037.0: 'Indian diaspora',
#  41038.0: 'Indian city or region nec',
#  41039.0: 'Indian nec',
#  41040.0: 'Kashmiri',
#  41050.0: 'Maldivian',
#  41060.0: 'Mauritian',
#  41070.0: 'Nepalese',
#  41080.0: 'Pakistani nfs',
#  41081.0: 'Sindhi',
#  41088.0: 'Pakistani city or region nec',
#  41089.0: 'Pakistani nec',
#  41090.0: 'Parsi',
#  41100.0: 'Rohingya',
#  41110.0: 'Sri Lankan nfs',
#  41111.0: 'Sinhalese',
#  41112.0: 'Burgher',
#  41118.0: 'Sri Lankan city or region nec',
#  41119.0: 'Sri Lankan nec',
#  41120.0: 'Tamil',
#  41990.0: 'South Asian nec',
#  42000.0: 'Mainland and Buddhist South-East Asian',
#  42010.0: 'Balinese',
#  42020.0: 'Burmese/Bamar',
#  42030.0: 'Hmong',
#  42040.0: 'Karen',
#  42050.0: 'Khmer',
#  42060.0: 'Lao',
#  42070.0: 'Mon',
#  42080.0: 'Thai',
#  42090.0: 'Vietnamese',
#  42990.0: 'Mainland and Buddhist South-East Asian nec',
#  43000.0: 'Maritime and Muslim South-East Asian',
#  43010.0: 'Bruneian',
#  43020.0: 'Indonesian nfs',
#  43021.0: 'Acehnese',
#  43022.0: 'Javanese',
#  43023.0: 'Madurese',
#  43024.0: 'Moluccan',
#  43025.0: 'Sundanese',
#  43028.0: 'Indonesian city or region nec',
#  43029.0: 'Indonesian nec',
#  43030.0: 'Malay nfs',
#  43031.0: 'Kadazan',
#  43039.0: 'Malay nec',
#  43040.0: 'Timorese',
#  43990.0: 'Maritime and Muslim South-East Asian nec',
#  50000.0: 'East Asian',
#  51000.0: 'Chinese Asian',
#  51010.0: 'Chinese nfs',
#  51011.0: 'Hong Kong Chinese',
#  51012.0: 'Chinese diaspora',
#  51019.0: 'Chinese nec',
#  51020.0: 'Singaporean Chinese',
#  51030.0: 'Taiwanese Chinese',
#  51990.0: 'Chinese Asian nec',
#  52000.0: 'North-East Asian',
#  52010.0: 'Japanese nfs',
#  52011.0: 'Ainu',
#  52012.0: 'Burakamin',
#  52019.0: 'Japanese nec',
#  52020.0: 'Korean',
#  52030.0: 'Mongolian',
#  52040.0: 'Tibetan',
#  52990.0: 'North-East Asian nec',
#  60000.0: 'Latin American',
#  60010.0: 'Amerindian (indigenous peoples of South and Central America nec)',
#  61000.0: 'South American',
#  61020.0: 'Argentinian',
#  61030.0: 'Aymara',
#  61040.0: 'Bolivian',
#  61050.0: 'Brazilian',
#  61060.0: 'Chilean',
#  61070.0: 'Colombian',
#  61080.0: 'Ecuadorian',
#  61090.0: 'Paraguayan',
#  61100.0: 'Peruvian',
#  61110.0: 'Quechuan',
#  61120.0: 'Uruguayan',
#  61130.0: 'Venezuelan',
#  61990.0: 'South American nec',
#  62000.0: 'Central American',
#  62010.0: 'Costa Rican',
#  62020.0: 'Cuban',
#  62030.0: 'Dominican (Dominican Republic)',
#  62040.0: 'Filipino',
#  62050.0: 'Guatemalan',
#  62060.0: 'Honduran',
#  62070.0: 'Mayan',
#  62080.0: 'Mexican',
#  62090.0: 'Nicaraguan',
#  62100.0: 'Panamanian',
#  62110.0: 'Puerto Rican',
#  62120.0: 'Salvadorean',
#  62990.0: 'Central American nec',
#  70000.0: 'Caribbean',
#  71000.0: 'English-speaking Caribbean',
#  71010.0: 'Anguillan',
#  71020.0: 'Antiguan',
#  71030.0: 'Bahamian',
#  71040.0: 'Barbadian',
#  71050.0: 'Barbudan',
#  71060.0: 'Dominican (Dominica)',
#  71070.0: 'Guyanese',
#  71080.0: 'Jamaican',
#  71090.0: 'Trinidadian',
#  71990.0: 'English-speaking Caribbean nec',
#  72000.0: 'French or Dutch-speaking Caribbean',
#  72010.0: 'Antillais',
#  72020.0: 'Aruban',
#  72030.0: 'Curacaoan',
#  72040.0: 'Haitian',
#  72050.0: 'Surinamese',
#  72990.0: 'French or Dutch-speaking Caribbean nec',
#  80000.0: 'North American and Australasian',
#  81000.0: 'North American',
#  81010.0: 'American nfs',
#  81011.0: 'African American',
#  81012.0: 'Hispanic American',
#  81013.0: 'Asian American',
#  81019.0: 'American nec',
#  81020.0: 'Bermudan',
#  81030.0: 'Canadian nfs',
#  81031.0: 'Quebecois/French Canadian',
#  81032.0: 'Black Canadian',
#  81033.0: 'Asian Canadian',
#  81039.0: 'Canadian nec',
#  81040.0: 'Native North American Indian',
#  81990.0: 'North American nec',
#  82000.0: 'Australasian',
#  82010.0: 'Australian nfs',
#  82011.0: 'Australian Aboriginal',
#  82012.0: 'Australian South Sea Islander',
#  82013.0: 'Torres Strait Islander',
#  82019.0: 'Australian nec',
#  82020.0: 'Fijian/iTaukei',
#  82030.0: 'Maori',
#  82040.0: 'New Zealander',
#  82050.0: 'Papua New Guinean',
#  82060.0: 'Samoan',
#  82070.0: 'Tahitian (and other French Polynesian)',
#  82080.0: 'Tongan',
#  82990.0: 'Australasian nec',
#  444444.0: 'Not classifiable'}

# %%
def lookupEthnicity(code):
    try: return ethnicityLookup[code]
    except: np.nan

def lookupRegion(code):
    try: return regionLookup[code]
    except: return np.nan

df['anctry1_decoded'] = df.anctry1.apply(lookupEthnicity)
df['anctry2_decoded'] = df.anctry2.apply(lookupEthnicity)
df['region_decoded'] = df.region.apply(lookupRegion)
df
# Out:
#        imsmetn  imdfetn  impcntr  imbgeco  imueclt  imwbcnt cntry     idno  \
# 0          4.0      3.0      3.0      4.0      9.0      7.0    AT      1.0
# 1          2.0      2.0      2.0     10.0     10.0      5.0    AT      2.0
# 2          3.0      3.0      3.0      7.0      5.0      5.0    AT      3.0
# 3          1.0      2.0      1.0     10.0     10.0     10.0    AT      4.0
# 4          8.0      8.0      8.0     88.0     88.0     88.0    AT      6.0
# ...        ...      ...      ...      ...      ...      ...   ...      ...
# 24623      3.0      2.0      2.0     10.0      8.0      7.0    SK  69817.0
# 24624      4.0      4.0      4.0      1.0      0.0      0.0    SK  69844.0
# 24625      2.0      2.0      2.0      5.0      4.0      3.0    SK  69871.0
# 24626      2.0      3.0      3.0      5.0      4.0      7.0    SK  69902.0
# 24627      2.0      3.0      3.0      5.0      5.0      5.0    SK  69975.0
#
#        year  anctry1   anctry2 region   anctry1_decoded anctry2_decoded  \
# 0      2002      NaN       NaN    NaN              None            None
# 1      2002      NaN       NaN    NaN              None            None
# 2      2002      NaN       NaN    NaN              None            None
# 3      2002      NaN       NaN    NaN              None            None
# 4      2002      NaN       NaN    NaN              None            None
# ...     ...      ...       ...    ...               ...             ...
# 24623  2018  14100.0  555555.0  SK042  Roma/Gypsy/Sinti            None
# 24624  2018  14100.0  555555.0  SK041  Roma/Gypsy/Sinti            None
# 24625  2018  15130.0  555555.0  SK041        Slovak nfs            None
# 24626  2018  15130.0  555555.0  SK032        Slovak nfs            None
# 24627  2018  15130.0  555555.0  SK032        Slovak nfs            None
#
#              region_decoded
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 24623          Košický kraj
# 24624        Prešovský kraj
# 24625        Prešovský kraj
# 24626  Banskobystrický kraj
# 24627  Banskobystrický kraj
#
# [430870 rows x 15 columns]

# %%
len(df)
# Out:
# 430870

# %% [markdown]
# ### normalise immigration and xenophobia variables

# %%
df.imueclt.value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.imueclt = df.imueclt.replace({
    77.0: np.nan, 
    88.0: np.nan, 
    99.0: np.nan, 
})

# %%
df.imueclt.value_counts(dropna=False).sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
rightDirectionCols = [
    'imsmetn', 
    'imdfetn',
    'impcntr',   
    ]
wrongDirectionCols = [
    'imbgeco',
    'imueclt',  #77 Refusal, 88 Don't know, 99 No answer
    'imwbcnt',
    ]


for col in rightDirectionCols:
    df[f'{col}_norm'] = (df[col] - df[col].mean())/df[col].std()

for col in wrongDirectionCols:
    df[f'{col}_norm'] = -(df[col] - df[col].mean())/df[col].std()

df
# Out:
#        imsmetn  imdfetn  impcntr  imbgeco  imueclt  imwbcnt cntry     idno  \
# 0          4.0      3.0      3.0      4.0      9.0      7.0    AT      1.0
# 1          2.0      2.0      2.0     10.0     10.0      5.0    AT      2.0
# 2          3.0      3.0      3.0      7.0      5.0      5.0    AT      3.0
# 3          1.0      2.0      1.0     10.0     10.0     10.0    AT      4.0
# 4          8.0      8.0      8.0     88.0      NaN     88.0    AT      6.0
# ...        ...      ...      ...      ...      ...      ...   ...      ...
# 24623      3.0      2.0      2.0     10.0      8.0      7.0    SK  69817.0
# 24624      4.0      4.0      4.0      1.0      0.0      0.0    SK  69844.0
# 24625      2.0      2.0      2.0      5.0      4.0      3.0    SK  69871.0
# 24626      2.0      3.0      3.0      5.0      4.0      7.0    SK  69902.0
# 24627      2.0      3.0      3.0      5.0      5.0      5.0    SK  69975.0
#
#        year  anctry1  ...  region   anctry1_decoded anctry2_decoded  \
# 0      2002      NaN  ...     NaN              None            None
# 1      2002      NaN  ...     NaN              None            None
# 2      2002      NaN  ...     NaN              None            None
# 3      2002      NaN  ...     NaN              None            None
# 4      2002      NaN  ...     NaN              None            None
# ...     ...      ...  ...     ...               ...             ...
# 24623  2018  14100.0  ...   SK042  Roma/Gypsy/Sinti            None
# 24624  2018  14100.0  ...   SK041  Roma/Gypsy/Sinti            None
# 24625  2018  15130.0  ...   SK041        Slovak nfs            None
# 24626  2018  15130.0  ...   SK032        Slovak nfs            None
# 24627  2018  15130.0  ...   SK032        Slovak nfs            None
#
#              region_decoded imsmetn_norm  imdfetn_norm  impcntr_norm  \
# 0                       NaN     1.176814      0.210653      0.131665
# 1                       NaN    -0.271852     -0.518681     -0.575777
# 2                       NaN     0.452481      0.210653      0.131665
# 3                       NaN    -0.996185     -0.518681     -1.283220
# 4                       NaN     4.074146      3.857324      3.668878
# ...                     ...          ...           ...           ...
# 24623          Košický kraj     0.452481     -0.518681     -0.575777
# 24624        Prešovský kraj     1.176814      0.939987      0.839108
# 24625        Prešovský kraj    -0.271852     -0.518681     -0.575777
# 24626  Banskobystrický kraj    -0.271852      0.210653      0.131665
# 24627  Banskobystrický kraj    -0.271852      0.210653      0.131665
#
#        imbgeco_norm  imueclt_norm  imwbcnt_norm
# 0          0.276830     -1.371959      0.117138
# 1         -0.050053     -1.758623      0.224530
# 2          0.113389      0.174697      0.224530
# 3         -0.050053     -1.758623     -0.043951
# 4         -4.299521           NaN     -4.232249
# ...             ...           ...           ...
# 24623     -0.050053     -0.985295      0.117138
# 24624      0.440271      2.108017      0.493011
# 24625      0.222349      0.561361      0.331922
# 24626      0.222349      0.561361      0.117138
# 24627      0.222349      0.174697      0.224530
#
# [430870 rows x 21 columns]

# %%
len(df.index.unique())
# Out:
# 24891

# %%
len(df)
# Out:
# 430870

# %% [markdown]
# ### create indices

# %%
antiimmigrationCols = [
    'imsmetn_norm', 
    'imdfetn_norm',
    'impcntr_norm',   
    'imbgeco_norm',
    ]

xenophobiaCols = [
    'imueclt_norm',  
    'imwbcnt_norm',
    ]

df['index_antiimmigration'] = df[antiimmigrationCols].mean(axis=1)
df['index_xenophobia'] = df[xenophobiaCols].mean(axis=1)
df['index_all'] = df[antiimmigrationCols + xenophobiaCols].mean(axis=1)
df[['index_antiimmigration', 'index_xenophobia', 'index_all']]
# Out:
#        index_antiimmigration  index_xenophobia  index_all
# 0                   0.448990         -0.627411   0.090190
# 1                  -0.354091         -0.767047  -0.491743
# 2                   0.227047          0.199613   0.217902
# 3                  -0.712035         -0.901287  -0.775119
# 4                   1.825207         -4.232249   0.613716
# ...                      ...               ...        ...
# 24623              -0.173008         -0.434079  -0.260031
# 24624               0.849045          1.300514   0.999534
# 24625              -0.285990          0.446642  -0.041780
# 24626               0.073204          0.339249   0.161886
# 24627               0.073204          0.199613   0.115340
#
# [430870 rows x 3 columns]

# %%
df.to_csv('03_xenophobia/ESS/data/columnSubset_normalised_indeces.csv')

# %% [markdown]
# ### look at spain

# %%
spain = df[df.cntry == 'ES']

# %%
len(spain)
# Out:
# 17169

# %%
spain.region_decoded.value_counts(dropna=False)
# Out:
# NaN                           7844
# Andalucía                     1862
# Comunidad de Madrid           1312
# Cataluña                      1268
# Comunidad Valenciana           924
# Galicia                        622
# Castilla y León                544
# Castilla-La Mancha             448
# País Vasco                     427
# Canarias                       354
# Aragón                         308
# Extremadura                    252
# Región de Murcia               248
# Principado de Asturias         228
# Illes Balears                  180
# Cantabria                      130
# Comunidad Foral de Navarra     126
# La Rioja                        58
# Ciudad Autónoma de Ceuta        21
# Ciudad Autónoma de Melilla      13
# Name: region_decoded, dtype: int64

# %%
spain.region_decoded.isna().value_counts()
# Out:
# False    9325
# True     7844
# Name: region_decoded, dtype: int64

# %%
indeces = ['index_antiimmigration', 'index_xenophobia', 'index_all']

fig, axes = plt.subplots(
    nrows=1, 
    ncols=3, 
    figsize=(20, 6), 
    sharex=True
    )

for i, indexName in enumerate(indeces):

    (
        spain
        .groupby('region_decoded')
        [indexName]
        .mean()
        .sort_values()
        .plot(
            kind='barh', 
            title=indexName,
            ax=axes[i],
            )
        )

plt.tight_layout()
plt.savefig('03_xenophobia/indeces.png')
plt.show()
